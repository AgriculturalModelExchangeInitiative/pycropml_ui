# %%
from pycrop2ml_ui.model.MainMenu import main
main(local=False)
# Out:
# Output()
# Output()

# %%
# !conda list
# Out:
# # packages in environment at /home/midingoy/anaconda3/envs/crop2ml:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       1_gnu    conda-forge
# alabaster                 0.7.12                     py_0    conda-forge
# alsa-lib                  1.2.3                h516909a_0    conda-forge
# antlr4-python3-runtime    4.9.3                    pypi_0    pypi
# argh                      0.26.2          pyh9f0ad1d_1002    conda-forge
# argon2-cffi               21.3.0             pyhd8ed1ab_0    conda-forge
# argon2-cffi-bindings      21.2.0           py37h5e8e339_1    conda-forge
# arrow                     1.2.2              pyhd8ed1ab_0    conda-forge
# astroid                   2.6.6            py37h89c1867_0    conda-forge
# atk-1.0                   2.36.0               h3371d22_4    conda-forge
# ...
