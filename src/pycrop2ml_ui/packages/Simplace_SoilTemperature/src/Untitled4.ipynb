# %%
sum(seq(0,1000,3)[seq(0,1000,3)%%3 == 0 | seq(0,1000,3)%%5 == 0])
# Out:
# [1] 166833

# %%
seq(0,1000,3)[seq(1,1000,3) == 0 | seq(1,1000,5) == 0]
# Out:
# Warning message in seq(1, 1000, 3) == 0 | seq(1, 1000, 5) == 0:
# “longer object length is not a multiple of shorter object length”
# numeric(0)

# %%
!install.packages("comprehenr")
# Out:
# Installing package into ‘/home/midingoy/R/x86_64-pc-linux-gnu-library/3.6’
# (as ‘lib’ is unspecified)
# Error in !install.packages("comprehenr"): invalid argument type
# Traceback:

# %%
(1:1000 %% 3)
# Out:
#    [1] 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1
#   [38] 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2
#   [75] 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0
#  [112] 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1
#  [149] 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2
#  [186] 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0
#  [223] 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1
#  [260] 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2
#  [297] 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0
#  [334] 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1
#  [371] 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2
#  [408] 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0
# ...

# %%
seq(1,1000,3)
# Out:
#   [1]    1    4    7   10   13   16   19   22   25   28   31   34   37   40   43
#  [16]   46   49   52   55   58   61   64   67   70   73   76   79   82   85   88
#  [31]   91   94   97  100  103  106  109  112  115  118  121  124  127  130  133
#  [46]  136  139  142  145  148  151  154  157  160  163  166  169  172  175  178
#  [61]  181  184  187  190  193  196  199  202  205  208  211  214  217  220  223
#  [76]  226  229  232  235  238  241  244  247  250  253  256  259  262  265  268
#  [91]  271  274  277  280  283  286  289  292  295  298  301  304  307  310  313
# [106]  316  319  322  325  328  331  334  337  340  343  346  349  352  355  358
# [121]  361  364  367  370  373  376  379  382  385  388  391  394  397  400  403
# [136]  406  409  412  415  418  421  424  427  430  433  436  439  442  445  448
# [151]  451  454  457  460  463  466  469  472  475  478  481  484  487  490  493
# [166]  496  499  502  505  508  511  514  517  520  523  526  529  532  535  538
# ...
